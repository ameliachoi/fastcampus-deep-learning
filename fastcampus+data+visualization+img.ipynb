# %% [markdown]
# <a href="https://colab.research.google.com/github/ameliachoi/fastcampus-deep-learning/blob/main/fastcampus%2Bdata%2Bvisualization%2Bimg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### image data visualization

# %%
# package

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path = '/content/dog.png'
image_pil = Image.open(path)
image = np.array(image_pil)

# %% [markdown]
# ---

# %%
# 이미지 들여다보기

image.shape
# Out:
# (510, 525, 4)

# %%
np.min(image), np.max(image)
# Out:
# (0, 255)

# %%
# 그래프로 시각화하기

plt.hist(image.ravel(), 256, [0, 256])
plt.show()

# %%
# 그림 나타내기
plt.imshow(image)
plt.show()

# %%
# 이미지 흑백으로 열기

image_pil = Image.open(path).convert('L')
image_bw = np.array(image_pil)

# %%
image_bw.shape
# Out:
# (510, 525)

# %%
# 흑백 이미지 열기

plt.imshow(image_bw, 'gray')
plt.show()

# %%
# 다른 색상으로 cmap 표현
plt.imshow(image_bw)
plt.show()

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %%
plt.imshow(image_bw, 'jet')
plt.show()

# %%
# colorbar 추가하기

plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %%
# image 보기 사이즈 조절

plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.show()

# %%
plt.title('dog')
plt.imshow(image)
plt.show()

# %% [markdown]
# ---

# %%
# 두번째 이미지 열기

cat_path = '/content/cat.png'
cat_pil = Image.open(cat_path)
cat_image = np.array(cat_pil)

# %%
plt.imshow(cat_image)
plt.show()

# %%
cat_image.shape
# Out:
# (315, 512, 4)

# %%
image.shape, cat_image.shape
# Out:
# ((510, 525, 4), (315, 512, 4))

# %%
# 이미지 겹치기 위해 준비하기

import cv2

# %%
dog_image = cv2.resize(image, (512, 315))
dog_image.shape
# Out:
# (315, 512, 4)

# %%
dog_image.shape, cat_image.shape
# Out:
# ((315, 512, 4), (315, 512, 4))

# %%
plt.imshow(dog_image)
plt.imshow(cat_image, alpha=.5) # 투명도 주기
plt.show()

# %%
# subplot

plt.figure(figsize=(10, 10))

plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(image_bw, 'gray')
plt.subplot(223)
plt.imshow(cat_image)
plt.show()
